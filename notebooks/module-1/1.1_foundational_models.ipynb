# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="google_genai:gemini-2.5-flash")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content="The Moon doesn't have a capital.\n\nIt's not a country or a political entity, and there are no permanent human settlements or governments on the Moon that would designate a capital city.\n\nIf humanity were to establish a permanent colony or a unified lunar government in the future, then a capital might be designated – perhaps the first major lunar city or research base would take on that role. But for now, it's just a celestial body!", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e0592-9bfa-74e3-8763-d952fb23e9f0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 610, 'total_tokens': 620, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 518}})

# %%
print(response.content)
# Out:
# The Moon doesn't have a capital.
#
# It's not a country or a political entity, and there are no permanent human settlements or governments on the Moon that would designate a capital city.
#
# If humanity were to establish a permanent colony or a unified lunar government in the future, then a capital might be designated – perhaps the first major lunar city or research base would take on that role. But for now, it's just a celestial body!

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'STOP',
#  'model_name': 'gemini-2.5-flash',
#  'model_provider': 'google_genai',
#  'safety_ratings': []}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="google_genai:gemini-2.5-flash",
    # Kwargs passed to the model:
    temperature=1.0,
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital.
#
# It's not a country or a political entity, and there are no permanent human settlements or governments established on its surface that would require a capital city. While various nations have sent probes and astronauts, and there are discussions about future lunar bases, none of these constitute a "capital."

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city in the way Earth does. It's a celestial body without any human settlements or governments.
#
# So, the answer is: **The Moon has no capital.**

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("google_genai:gemini-2.5-flash")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='4b678e5f-daf9-4b93-92a0-3e803af7cc1e'),
#               AIMessage(content='That\'s a fun question! The Moon doesn\'t have a capital city in the way Earth does. It\'s a celestial body without any human settlements or governments.\n\nHowever, if you were to get creative and imagine a "capital," you might think of:\n\n*   **The Sea of Tranquility (Mare Tranquillitatis):** This is where the Apollo 11 mission landed, making it a historically significant location for humanity\'s first steps on the Moon.\n*   **A hypothetical future lunar base:** If humans establish a permanent presence, a main settlement or research station could eventually be considered the "capital."\n\nBut in reality, the Moon has no capital!', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e059e-cd5e-7af2-870c-d3cba90874b0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 140, 'total_tokens': 150, 'input_token_details': {'cache_read': 0}})]}

# %%
print(response['messages'][-1].content)

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='e5300e32-c675-46c5-9360-bc39f46b6a3a'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='c0fe5352-4e7b-4240-9edc-ac20cc1c9f5f', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='ae3049c3-f6c3-43ec-a40a-fd8a0dcbdcf1'),
#               AIMessage(content='Luna City is a fictional city on the Moon. It\'s been featured in many science fiction stories and has been described in various ways depending on the author\'s imagination.\n\nHere are some common elements and ideas about Luna City you might find in science fiction:\n\n*   **Location:** It\'s often depicted as being built **inside** a large crater or a lava tube for protection from radiation and micrometeoroids. Sometimes it\'s shown as a domed city on the surface.\n*   **Architecture:** Due to the Moon\'s lower gravity and lack of atmosphere, architecture can be quite different from Earth. You might see:\n    *   **Tall, slender structures:** The lower gravity allows for much taller buildings.\n    *   **Underground or domed habitats:** Essential for shielding from the harsh lunar environment.\n    *   **Minimalist and functional designs:** Focusing on efficiency and survival.\n    *   **Transparent materials:** To allow views of the Earth or the lunar landscape.\n*   **Purpose:** Luna City often serves as:\n    *   **A research outpost:** Studying lunar geology, astronomy, or the effects of low gravity.\n    *   **A mining colony:** Extracting valuable resources like Helium-3 or rare minerals.\n    *   **A tourist destination:** Offering unique experiences like low-gravity sports or breathtaking views of Earth.\n    *   **A stepping stone for further space exploration:** A base for missions to Mars or beyond.\n*   **Society and Culture:** The inhabitants of Luna City are often portrayed as:\n    *   **Highly skilled individuals:** Scientists, engineers, miners, and astronauts.\n    *   **Resourceful and adaptable:** Living in a challenging environment.\n    *   **Having a unique culture:** Shaped by their isolation and the constant presence of Earth in their sky.\n    *   **Potentially facing social stratification:** Between those who can afford to live comfortably and those working in more dangerous conditions.\n*   **Technology:** Advanced technology is a given, including:\n    *   **Life support systems:** Crucial for breathable air and stable temperatures.\n    *   **Advanced transportation:** Lunar rovers, maglev trains, or even personal flight suits.\n    *   **Artificial gravity:** Some stories might include areas with simulated Earth gravity for health and comfort.\n    *   **Energy generation:** Solar power is a likely candidate, but other advanced methods might be employed.\n\n**Notable Fictional Depictions:**\n\n*   **"The Moon is a Harsh Mistress" by Robert A. Heinlein:** Features a lunar colony called **Luna** that becomes a free society. While not explicitly called "Luna City," it functions as the central settlement.\n*   **"Space Odyssey" series by Arthur C. Clarke:** Features a lunar base called **Clavius Base**, which could be considered a precursor to a city.\n*   **Various video games and comic books:** Often depict bustling lunar cities with unique aesthetics and challenges.\n\n**In essence, Luna City is a testament to humanity\'s drive to explore and colonize new frontiers. It represents a vision of our future in space, filled with both immense challenges and incredible possibilities.**\n\nSince it\'s fictional, its exact details can vary wildly! What aspects of Luna City are you most curious about?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e059e-f3f1-7a53-8d89-24df754e0075-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 29, 'output_tokens': 692, 'total_tokens': 721, 'input_token_details': {'cache_read': 0}})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content = "I'm learning Agentic AI. Give me tutorial.")]},
    stream_mode = "messages"
):
    if token.content:
        print(token.content, end = "", flush = True)
# Out:
# Let's dive into the exciting world of Agentic AI! This tutorial will guide you from the foundational concepts to building your first simple agent.
#
# ## Agentic AI Tutorial: Building Intelligent Agents
#
# ### What is Agentic AI?
#
# At its core, Agentic AI refers to systems that are designed to act autonomously and intelligently in an environment to achieve specific goals. Think of them as digital agents that can perceive their surroundings, make decisions, and take actions.
#
# **Key characteristics of an agent:**
#
# *   **Perception:** Agents can sense their environment through sensors (e.g., cameras, microphones, data feeds).
# *   **Decision-Making:** Based on their perceptions and internal goals, agents use reasoning and logic to decide what to do.
# *   **Action:** Agents can affect their environment through actuators (e.g., robotic arms, software commands, generating text).
# *   **Autonomy:** Agents operate with a degree of independence, without constant human intervention.
# *   **Goal-Oriented:** Agents are designed to achieve specific objectives.
#
# ### Why is Agentic AI Important?
#
# Agentic AI is revolutionizing how we interact with technology and solve complex problems. It enables:
#
# *   **Automation:** Automating repetitive or complex tasks.
# *   **Personalization:** Creating highly tailored experiences for users.
# *   **Problem Solving:** Tackling challenges that are too complex or dangerous for humans.
# *   **Enhanced Efficiency:** Optimizing processes and resource allocation.
# *   **New Capabilities:** Enabling entirely new applications and services.
#
# ### Core Components of an Agentic AI System
#
# While the complexity can vary greatly, most agentic AI systems share these fundamental components:
#
# 1.  **Environment:** The world or system in which the agent operates. This can be physical (a robot in a factory) or digital (a chatbot interacting with a user, a trading bot on a stock market).
# 2.  **Perception Module:** This module takes in information from the environment. For a physical robot, it might be camera feeds and sensor readings. For a chatbot, it's user input (text, voice).
# 3.  **Reasoning/Decision-Making Module (The "Brain"):** This is where the intelligence lies. It processes the perceived information, considers the agent's goals, and decides on the next action. This often involves:
#     *   **Knowledge Representation:** How the agent stores and accesses information about the world and itself.
#     *   **Planning:** Devising a sequence of actions to achieve a goal.
#     *   **Learning:** Adapting and improving its behavior over time.
#     *   **Task Decomposition:** Breaking down complex goals into smaller, manageable sub-tasks.
# 4.  **Action Module:** This module translates the agent's decisions into actions that affect the environment.
#
# ### Types of Agents (A Simplified View)
#
# *   **Simple Reflex Agents:** Act based solely on the current percept, ignoring history. (e.g., a thermostat)
# *   **Model-Based Reflex Agents:** Maintain an internal "model" of the environment to track its state, allowing for more informed decisions.
# *   **Goal-Based Agents:** Act to achieve explicit goals. They consider the consequences of their actions.
# *   **Utility-Based Agents:** Aim to maximize a "utility" function, which represents happiness or desirability. They can make trade-offs when multiple options exist.
# *   **Learning Agents:** Agents that can improve their performance through experience.
#
# ### Let's Build a Simple Agent!
#
# We'll create a text-based agent that can respond to simple commands. This agent will have a basic "brain" that understands a few instructions and can perform corresponding actions.
#
# **Concept:** A "Task Manager Agent" that can add tasks, list tasks, and mark tasks as complete.
#
# **Tools:** We'll use Python for its simplicity and extensive libraries. For more advanced agents, you might use frameworks like LangChain or LlamaIndex.
#
# ---
#
# #### **Step 1: Setting Up Your Environment**
#
# Make sure you have Python installed. You can download it from [python.org](https://www.python.org/).
#
# #### **Step 2: Designing the Agent's "Brain"**
#
# We need to store the agent's "knowledge" and "goals." In this case, our knowledge will be the list of tasks.
#
# ```python
# class TaskManagerAgent:
#     def __init__(self):
#         self.tasks = []  # Our agent's "memory" or knowledge base
#         self.goal = "Manage tasks efficiently." # The agent's overarching goal
#
#     def perceive(self, user_input):
#         """
#         This method simulates the agent perceiving the environment (user input).
#         """
#         print(f"Agent perceives: '{user_input}'")
#         return user_input.lower().strip() # Normalize input
#
#     def decide_action(self, perceived_data):
#         """
#         This is the core decision-making logic.
#         It interprets the perceived data and determines the best action.
#         """
#         if perceived_data.startswith("add task:"):
#             task_description = perceived_data.replace("add task:", "").strip()
#             if task_description:
#                 return {"action": "add_task", "payload": task_description}
#             else:
#                 return {"action": "error", "message": "Please provide a task description."}
#         elif perceived_data == "list tasks":
#             return {"action": "list_tasks"}
#         elif perceived_data.startswith("complete task:"):
#             task_index_str = perceived_data.replace("complete task:", "").strip()
#             try:
#                 task_index = int(task_index_str) - 1 # User-friendly 1-based indexing
#                 return {"action": "complete_task", "payload": task_index}
#             except ValueError:
#                 return {"action": "error", "message": "Invalid task number. Please provide a number."}
#         elif perceived_data in ["exit", "quit", "bye"]:
#             return {"action": "exit"}
#         else:
#             return {"action": "unknown", "message": "I don't understand that command."}
#
#     def perform_action(self, decision):
#         """
#         This method simulates the agent acting on the environment.
#         """
#         action_type = decision.get("action")
#         payload = decision.get("payload")
#         message = decision.get("message")
#
#         if action_type == "add_task":
#             self.tasks.append({"description": payload, "completed": False})
#             print(f"Agent acts: Added task '{payload}'.")
#         elif action_type == "list_tasks":
#             if not self.tasks:
#                 print("Agent acts: No tasks to show.")
#             else:
#                 print("Agent acts: Here are your tasks:")
#                 for i, task in enumerate(self.tasks):
#                     status = "[X]" if task["completed"] else "[ ]"
#                     print(f"{i+1}. {status} {task['description']}")
#         elif action_type == "complete_task":
#             if 0 <= payload < len(self.tasks):
#                 self.tasks[payload]["completed"] = True
#                 print(f"Agent acts: Marked task '{self.tasks[payload]['description']}' as complete.")
#             else:
#                 print(f"Agent acts: Error - Task index {payload+1} is out of bounds.")
#         elif action_type == "error":
#             print(f"Agent acts: Error - {message}")
#         elif action_type == "unknown":
#             print(f"Agent acts: {message}")
#         elif action_type == "exit":
#             print("Agent acts: Goodbye!")
#             return False # Signal to stop the loop
#         return True # Signal to continue
#
#     def run(self):
#         """
#         The main loop for the agent to interact with the environment.
#         """
#         print(f"Agent initialized. Goal: {self.goal}")
#         running = True
#         while running:
#             user_input = input("You: ")
#             perceived_data = self.perceive(user_input)
#             decision = self.decide_action(perceived_data)
#             running = self.perform_action(decision)
#
# ```
#
# #### **Step 3: Running the Agent**
#
# Now, let's instantiate and run our agent.
#
# ```python
# if __name__ == "__main__":
#     task_agent = TaskManagerAgent()
#     task_agent.run()
# ```
#
# ---
#
# **How to Use Your Agent:**
#
# 1.  Save the code above as a Python file (e.g., `agent_tutorial.py`).
# 2.  Open your terminal or command prompt.
# 3.  Navigate to the directory where you saved the file.
# 4.  Run the script using: `python agent_tutorial.py`
#
# **Example Interaction:**
#
# ```
# Agent initialized. Goal: Manage tasks efficiently.
# You: add task: Buy groceries
# Agent perceives: 'add task: buy groceries'
# Agent acts: Added task 'Buy groceries'.
# You: add task: Finish report
# Agent perceives: 'add task: finish report'
# Agent acts: Added task 'Finish report'.
# You: list tasks
# Agent perceives: 'list tasks'
# Agent acts: Here are your tasks:
# 1. [ ] Buy groceries
# 2. [ ] Finish report
# You: complete task: 1
# Agent perceives: 'complete task: 1'
# Agent acts: Marked task 'Buy groceries' as complete.
# You: list tasks
# Agent perceives: 'list tasks'
# Agent acts: Here are your tasks:
# 1. [X] Buy groceries
# 2. [ ] Finish report
# You: what is the weather like?
# Agent perceives: 'what is the weather like?'
# Agent acts: I don't understand that command.
# You: exit
# Agent perceives: 'exit'
# Agent acts: Goodbye!
# ```
#
# ---
#
# ### Expanding Your Agent: Next Steps and Concepts
#
# This is a very basic example, but it illustrates the core loop of perception, decision, and action. Here's how you can build upon this foundation:
#
# 1.  **More Sophisticated Reasoning:**
#     *   **Natural Language Understanding (NLU):** Instead of simple keyword matching, use libraries like `spaCy` or `NLTK` to understand the intent and entities in user input.
#     *   **State Management:** For more complex agents, you'll need to manage internal states beyond just a list of tasks. This could involve tracking conversation history, user preferences, or the status of ongoing operations.
#     *   **Planning Algorithms:** For agents that need to achieve multi-step goals, explore algorithms like A* search or hierarchical task networks (HTN).
#
# 2.  **Integration with External Tools (Tool Use):**
#     *   **APIs:** Agents can interact with the real world by calling APIs. For example, a weather agent would use a weather API.
#     *   **Databases:** Store and retrieve information from databases.
#     *   **Web Scraping:** Gather information from websites.
#     *   **LLMs (Large Language Models):** This is where Agentic AI gets really powerful. LLMs can act as the "brain" for complex reasoning, planning, and even code generation.
#
# 3.  **Learning and Adaptation:**
#     *   **Reinforcement Learning:** Agents learn by trial and error, receiving rewards or penalties for their actions.
#     *   **Supervised Learning:** Train agents on labeled data to perform specific tasks.
#     *   **Few-Shot/Zero-Shot Learning (with LLMs):** Leverage LLMs to perform tasks with minimal or no prior training data.
#
# 4.  **Agent Frameworks:**
#     *   **LangChain:** A popular framework for developing applications powered by LLMs. It provides abstractions for building agents, managing prompts, and chaining LLM calls.
#     *   **LlamaIndex:** Focuses on connecting LLMs to your external data.
#     *   **Auto-GPT/BabyAGI (Conceptual Examples):** These are early examples of autonomous agents that use LLMs to break down goals and execute them.
#
# ### Example: Using an LLM as the Agent's Brain (Conceptual)
#
# Imagine replacing our `decide_action` and `perform_action` with calls to a powerful LLM.
#
# ```python
# # (Conceptual - requires an LLM API like OpenAI, Anthropic, etc.)
# import openai # Or your chosen LLM library
#
# class LLMAgent:
#     def __init__(self, api_key):
#         openai.api_key = api_key
#         self.tasks = []
#         self.goal = "Manage tasks efficiently."
#
#     def perceive(self, user_input):
#         return user_input
#
#     def decide_action_with_llm(self, perceived_data):
#         prompt = f"""
#         You are a Task Manager Agent. Your goal is to manage tasks efficiently.
#         You have access to the following commands:
#         - add task: [description]
#         - list tasks
#         - complete task: [task_number]
#         - exit
#
#         Current tasks: {self.tasks}
#
#         User input: "{perceived_data}"
#
#         What is the best action to take? Respond in JSON format with 'action' and 'payload' (if any).
#         Example: {{"action": "add_task", "payload": "Buy milk"}}
#         Example: {{"action": "list_tasks"}}
#         Example: {{"action": "complete_task", "payload": 1}}
#         Example: {{"action": "exit"}}
#         Example: {{"action": "error", "message": "Invalid command"}}
#         """
#
#         response = openai.Completion.create(
#             model="text-davinci-003", # Or a newer model like gpt-3.5-turbo/gpt-4
#             prompt=prompt,
#             max_tokens=100,
#             temperature=0.1
#         )
#         try:
#             # In a real scenario, you'd parse the LLM output more robustly
#             # and handle potential JSON parsing errors.
#             import json
#             action_data = json.loads(response.choices[0].text.strip())
#             return action_data
#         except Exception as e:
#             print(f"LLM parsing error: {e}")
#             return {"action": "error", "message": "Failed to parse LLM response."}
#
#     def perform_action(self, decision):
#         # This part would be similar to the previous example,
#         # but triggered by the LLM's decision.
#         action_type = decision.get("action")
#         payload = decision.get("payload")
#         message = decision.get("message")
#
#         if action_type == "add_task":
#             self.tasks.append({"description": payload, "completed": False})
#             print(f"Agent acts: Added task '{payload}'.")
#         elif action_type == "list_tasks":
#             if not self.tasks:
#                 print("Agent acts: No tasks to show.")
#             else:
#                 print("Agent acts: Here are your tasks:")
#                 for i, task in enumerate(self.tasks):
#                     status = "[X]" if task["completed"] else "[ ]"
#                     print(f"{i+1}. {status} {task['description']}")
#         elif action_type == "complete_task":
#             if 0 <= payload < len(self.tasks):
#                 self.tasks[payload]["completed"] = True
#                 print(f"Agent acts: Marked task '{self.tasks[payload]['description']}' as complete.")
#             else:
#                 print(f"Agent acts: Error - Task index {payload+1} is out of bounds.")
#         elif action_type == "error":
#             print(f"Agent acts: {message}")
#         elif action_type == "exit":
#             print("Agent acts: Goodbye!")
#             return False
#         return True
#
#     def run(self):
#         print(f"Agent initialized. Goal: {self.goal}")
#         running = True
#         while running:
#             user_input = input("You: ")
#             perceived_data = self.perceive(user_input)
#             decision = self.decide_action_with_llm(perceived_data)
#             running = self.perform_action(decision)
#
# # To run this conceptual example, you'd need to:
# # 1. Install the OpenAI library: pip install openai
# # 2. Get an OpenAI API key.
# # 3. Replace "YOUR_OPENAI_API_KEY" with your actual key.
# # 4. Uncomment and run the following:
# # if __name__ == "__main__":
# #     llm_agent = LLMAgent(api_key="YOUR_OPENAI_API_KEY")
# #     llm_agent.run()
# ```
#
# This conceptual example shows how an LLM can interpret more natural language and decide on actions. This is the foundation for many advanced agentic AI systems.
#
# ### Conclusion
#
# You've taken your first steps into Agentic AI! You've learned about the core concepts, components, and even built a simple text-based agent. The field is rapidly evolving, so keep exploring, experimenting, and building!
#
# **Key Takeaways:**
#
# *   Agents perceive, decide, and act.
# *   The "brain" of an agent is its reasoning and decision-making module.
# *   LLMs are powerful tools for building more intelligent and flexible agents.
# *   Frameworks like LangChain simplify agent development.
#
# Happy building!
